# %% [markdown]
# # Exercise 1 Notebook

# %% [markdown]
# ## Install Ydata profiling library

# %%
# %pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.8/357.8 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 10.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.7 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=f531c0c15495690383278b1464ad35ff749dc2fabadfc331a7b8e10c07863cb9
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: typing-extensions
# ...

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Load CSV file containing dataset into Pandas DataFrame

# %%
url = 'https://raw.githubusercontent.com/NSCC-ITC-Winter2024-DBAS5125-700-MCr/exercise-1-pdushie/main/Titanic_dataset.csv?token=GHSAT0AAAAAACMTSD7J64NCAPKWRWNOEUQSZM5ORRQ'
df = pd.read_csv(url)
df.info() #Show some info about the columns and data types in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# ## Describe the data using Pandas "describe"

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch         fare        body
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000  121.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027    33.295479  160.809917
# std       0.837836     0.486055    14.413500     1.041658     0.865560    51.758668   97.696922
# min       1.000000     0.000000     0.166700     0.000000     0.000000     0.000000    1.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000     7.895800   72.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000    14.454200  155.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000    31.275000  256.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000   512.329200  328.000000

# %% [markdown]
# ## Describe data using Ydata profiling tool

# %%
profile = ProfileReport(df, title = "Titanic Dataset Profiling Report")
#profile.to_html("TitanicReport.html")
profile.to_file("report_timeseries.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
